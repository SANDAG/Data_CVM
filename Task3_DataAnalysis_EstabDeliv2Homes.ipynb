# %% [markdown]
# ### SANDAG Commercial Vehicle Model
# #### Task 3 -- Data Exploration for Design Decisions

# %% [markdown]
# #### Tabulate weighted establishment deliveries to residences/households

# %%
import numpy as np
import pandas as pd
import os
# from matplotlib import pyplot as plt
# from matplotlib import ticker

# %%
pd.set_option("display.max_rows", None)

# %%
# Import file paths from script
from FilePaths import *
print("root_dir = \n", root_dir, "\n")
print("raw_data_dir = \n", raw_data_dir,"\n")
print("proc_data_dir = \n", proc_data_dir,"\n")
print("lookup_dir = \n", lookup_dir,"\n")
# Out:
# root_dir =
#  C:\Users\jgliebe\OneDrive - Cambridge Systematics\Documents - PROJ SANDAG Commercial Vehicle & Heavy Truck Model Update\_Shared_CSTeam
#
# raw_data_dir =
#  Task03_DataID_Review
#
# proc_data_dir =
#  Task04_DataProcessing\Data\proc data\v10
#
# lookup_dir =
#  Task04_DataProcessing\Data\Lookups

# %%
# Read input data -- establishment file
df_estab = pd.read_excel(os.path.join(root_dir, 
                                      raw_data_dir, 
                                      r"CVS\SANDAG 2022 CV DataBase & Dictionaires_03_03_2023.xlsx"),
                                     sheet_name=r"Establishment Data")

df_estab.set_index('company_id')
df_estab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2697 entries, 0 to 2696
# Data columns (total 68 columns):
# company_id                                                               2697 non-null int64
# Industry Group_Size Code (Group from Column D; Size 1=0-9 emp, 2=10+)    2697 non-null object
# company_name                                                             2697 non-null object
# base_location_Industry Group                                             2697 non-null int64
# company_location_address                                                 2697 non-null object
# company_location_city                                                    2697 non-null object
# company_location_state                                                   2697 non-null object
# company_location_zipcode                                                 2697 non-null int64
# company_location_latitude                                                2697 non-null float64
# company_location_longitude                                               2697 non-null float64
# employees_fulltime_count                                                 2697 non-null int64
# employees_parttime_count                                                 2697 non-null int64
# no_of_emp_work                                                           2697 non-null int64
# Number of Employess (1=<10, 2=10+)                                       2697 non-null int64
# total_telecommute_from_home                                              2697 non-null int64
# is_use_tnc                                                               2697 non-null int64
# no_of_deliveries                                                         2697 non-null int64
# no_of_deliveries_pcsuvpu                                                 2695 non-null float64
# no_of_deliveries_su                                                      2695 non-null float64
# no_of_deliveries_cu                                                      2695 non-null float64
# per_of_deliveries_warehouse                                              2181 non-null float64
# per_of_deliveries_airport                                                2181 non-null float64
# per_of_deliveries_manufacture                                            2181 non-null float64
# per_of_deliveries_retail                                                 2181 non-null float64
# per_of_deliveries_service                                                2181 non-null float64
# per_of_deliveries_other                                                  2181 non-null float64
# per_of_deliveries_dontknow                                               2181 non-null float64
# per_of_deliveries_text_other                                             363 non-null object
# no_of_from_deliveries                                                    2697 non-null int64
# no_of_from_deliveries_pcsuvpu                                            2694 non-null float64
# no_of_from_deliveries_su                                                 2679 non-null float64
# no_of_from_deliveries_cu                                                 2694 non-null float64
# per_of_from_deliveries_warehouse                                         1070 non-null float64
# per_of_from_deliveries_airport                                           1070 non-null float64
# per_of_from_deliveries_manufacture                                       1070 non-null float64
# per_of_from_deliveries_retail                                            1070 non-null float64
# per_of_from_deliveries_service                                           1070 non-null float64
# per_of_from_deliveries_other                                             1070 non-null float64
# per_of_from_deliveries_dontknow                                          1070 non-null float64
# per_of_from_deliveries_text_other                                        453 non-null object
# has_vehicles                                                             2697 non-null int64
# vehicle_count_total                                                      1058 non-null float64
# vehicle_axle_cargotruck                                                  1048 non-null float64
# vehicle_semi_cargo                                                       1045 non-null float64
# vehicle_cars_count                                                       1052 non-null float64
# vehicle_pickuptrucks_count                                               1043 non-null float64
# vehicle_cargovans_count                                                  1042 non-null float64
# vehicle_servicevans_count                                                1042 non-null float64
# use_personal_vehicle                                                     2697 non-null int64
# vehicle_other_count_total                                                662 non-null float64
# vehicle_other_axle_cargotruck                                            662 non-null float64
# vehicle_other_semi_cargo                                                 662 non-null float64
# vehicle_other_cars_count                                                 662 non-null float64
# vehicle_other_pickuptrucks_count                                         662 non-null float64
# vehicle_other_cargovans_count                                            662 non-null float64
# vehicle_other_servicevans_count                                          662 non-null float64
# vehicle_toll_trans_count                                                 2697 non-null int64
# Participated in Travel Survey?                                           2697 non-null object
# LCV Owned or Leased                                                      2697 non-null int64
# LCV other                                                                2697 non-null int64
# LCV Total                                                                2697 non-null int64
# SUT Owned or Leased                                                      2697 non-null int64
# SUT other                                                                2697 non-null int64
# SUT Total                                                                2697 non-null int64
# MUT Owned or Leased                                                      2697 non-null int64
# MUT other                                                                2697 non-null int64
# MUT Total                                                                2697 non-null int64
# TOTAL CVs                                                                2697 non-null int64
# dtypes: float64(36), int64(24), object(8)
# memory usage: 1.4+ MB

# %%
# Read input data -- establishment file
df_trips = pd.read_excel(os.path.join(root_dir, 
                                      raw_data_dir, 
                                      r"CVS\SANDAG 2022 CV DataBase & Dictionaires_03_03_2023.xlsx"),
                                     sheet_name=r"Trip Data")

df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 32 columns):
# company_id                            12261 non-null int64
# vehicle_id                            12261 non-null int64
# driver_id                             12261 non-null int64
# trip_number                           12261 non-null int64
# trip_load_status                      1582 non-null float64
# trip_load_weight                      191 non-null float64
# activity_type                         12261 non-null int64
# activity_type_other                   700 non-null object
# placetype                             12261 non-null int64
# placetype_other                       1175 non-null object
# location_placename                    12261 non-null object
# location_address                      12261 non-null object
# location_city                         12248 non-null object
# location_state                        12261 non-null object
# location_zip                          12261 non-null int64
# location_latitude                     12261 non-null float64
# location_longitude                    12261 non-null float64
# cargo_pickup                          276 non-null float64
# cargo_other_pickup                    6 non-null object
# cargo_delivery                        2002 non-null object
# cargo_other_delivery                  21 non-null object
# cargo_pu_weight                       276 non-null object
# cargo_do_weight                       2002 non-null object
# travel_date                           12261 non-null datetime64[ns]
# arrival_time                          10687 non-null object
# departure_time                        10687 non-null object
# used_other_vehicle                    12261 non-null int64
# participation_type                    12261 non-null object
# vehicle_id.1                          12261 non-null int64
# Lower Estimate Weight Factor          12261 non-null float64
# Most Likely Estimate Weight Factor    12261 non-null float64
# Upper Estimate Weight Factor          12261 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(9), object(14)
# memory usage: 3.0+ MB

# %%
indus_lookup = {
1: "Agriculture/Mining",
2: "Manufacturing",
3: "Industrial/Utilities",
4: "Retail",
5: "Wholesale",
6: "Construction",
7: "Transportation",
8: "Info/Finance/Insurance/Real Estate/Professional services",
9: "Education/Other public services",
10: "Medical/Health Services",
11: "Leisure/Accommodations and Food",
96: "Other/Non-Classified"
}

# %%
# Get establishment employment
df_empl = df_estab[['company_id','base_location_Industry Group']].reset_index()
df_empl['industry_group'] = df_empl['base_location_Industry Group'].map(indus_lookup)
df_empl.loc[:, 'emp_total'] = df_estab['employees_fulltime_count']+df_estab['employees_parttime_count']
df_empl.set_index('company_id', inplace=True)
df_empl = df_empl.drop(['index','base_location_Industry Group'], axis=1)
df_empl.head()
# Out:
#                 industry_group  emp_total
# company_id
# 100002      Agriculture/Mining         50
# 100003      Agriculture/Mining          2
# 100004      Agriculture/Mining          4
# 100005      Agriculture/Mining         34
# 100007      Agriculture/Mining          5

# %%
# Join establishment total employment to routes records
df_trips = df_trips.merge(df_empl, how='left', on='company_id')
df_trips[['emp_total']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12261 entries, 0 to 12260
# Data columns (total 1 columns):
# emp_total    12261 non-null int64
# dtypes: int64(1)
# memory usage: 191.6 KB

# %%
df_trips.head()
# Out:
#    company_id  vehicle_id  driver_id  trip_number  trip_load_status  \
# 0      100012        2062       2589            0               4.0
# 1      100012        2062       2589            1               NaN
# 2      100012        2062       2589            2               NaN
# 3      100012        2062       2589            3               NaN
# 4      100012        2062       2589            4               NaN
#
#    trip_load_weight  activity_type activity_type_other  placetype  \
# 0               NaN              1                 NaN         11
# 1               NaN             11                 NaN          6
# 2               NaN              1                 NaN         11
# 3               NaN             10                 NaN         96
# 4               NaN              1                 NaN         11
#
#   placetype_other  ... arrival_time departure_time used_other_vehicle  \
# 0             NaN  ...          NaN       10:00:00                  2
# 1             NaN  ...     10:20:00       11:10:00                  2
# 2             NaN  ...     11:22:00       11:40:00                  2
# 3       DOG PARK   ...     12:00:00       14:00:00                  2
# 4             NaN  ...     14:20:00            NaN                  2
#
#   participation_type  vehicle_id.1  Lower Estimate Weight Factor  \
# 0             online          2062                    109.693404
# 1             online          2062                    109.693404
# 2             online          2062                    109.693404
# 3             online          2062                    109.693404
# 4             online          2062                    109.693404
#
#    Most Likely Estimate Weight Factor  Upper Estimate Weight Factor  \
# 0                          177.825038                    198.177052
# 1                          177.825038                    198.177052
# 2                          177.825038                    198.177052
# 3                          177.825038                    198.177052
# 4                          177.825038                    198.177052
#
#                     industry_group emp_total
# 0  Education/Other public services         3
# 1  Education/Other public services         3
# 2  Education/Other public services         3
# 3  Education/Other public services         3
# 4  Education/Other public services         3
#
# [5 rows x 34 columns]

# %% [markdown]
# #### National Business Employment Dynamics Data by Firm Size Class
# * Size class 1 (1 to 4 employees)
# * Size class 2 (5 to 9 employees)
# * Size class 3 (10 to 19 employees)
# * Size class 4 (20 to 49 employees)
# * Size class 5 (50 to 99 employees)
# * Size class 6 (100 to 249 employees)
# * Size class 7 (250 to 499 employees)
# * Size class 8 (500 to 999 employees)
# * Size class 9 (1,000 or more employees)

# %%
# Create sizeClass dictionary
def sizeClass(emp=0):
    if emp in range(1, 5): return 1
    elif emp in range(5, 10): return 2
    elif emp in range(10, 20): return 3
    elif emp in range(20, 50): return 4
    elif emp in range(50, 100): return 5
    elif emp in range(100, 250): return 6
    elif emp in range(250, 500): return 7
    elif emp in range(500, 1000): return 8
    elif emp in range(1000, 9999): return 9
    else: return 0
    
df_trips.loc[:, 'emp_szclass'] = df_trips['emp_total'].map(sizeClass)

# %%
# Summarize
dft1 = df_trips.groupby(['industry_group','emp_szclass']).size().reset_index(name='n_trips')
dft2 = df_trips.groupby(['industry_group','emp_szclass'])['Most Likely Estimate Weight Factor'].sum().astype('int64').reset_index(name='wtd_trips')
df_sum = pd.merge(dft1, dft2)
df_sum.loc[:, 'n_trips'] = df_sum['n_trips'] #.map('{:,d}'.format)
df_sum.loc[:, 'wtd_trips'] = df_sum['wtd_trips'] #.map('{:,d}'.format)

pivot1 = pd.pivot_table(data = df_sum, 
                        values=['n_trips'], 
                        index='industry_group',
                        columns = 'emp_szclass', 
                        aggfunc=np.sum, fill_value=0, 
                        margins=True, margins_name='Totals').style.format('{:,.0f}')

pivot2 = pd.pivot_table(data = df_sum, 
                        values=['wtd_trips'], 
                        index='industry_group',
                        columns = 'emp_szclass', 
                        aggfunc=np.sum, fill_value=0, 
                        margins=True, margins_name='Totals').style.format('{:,.0f}')

# %%
print("Trips by Industry and Size Class -- Raw Count")
pivot1
# Out:
# Trips by Industry and Size Class -- Raw Count
# <style  type="text/css" >
# </style><table id="T_7e8a8f4a_3635_11ee_b87a_415645000030" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=8>n_trips</th>    </tr>    <tr>        <th class="index_name level1" >emp_szclass</th>        <th class="col_heading level1 col0" >1</th>        <th class="col_heading level1 col1" >2</th>        <th class="col_heading level1 col2" >3</th>        <th class="col_heading level1 col3" >4</th>        <th class="col_heading level1 col4" >5</th>        <th class="col_heading level1 col5" >6</th>        <th class="col_heading level1 col6" >7</th>        <th class="col_heading level1 col7" >Totals</th>    </tr>    <tr>        <th class="index_name level0" >industry_group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7e8a8f4a_3635_11ee_b87a_415645000030level0_row0" class="row_heading level0 row0" >Agriculture/Mining</th>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col0" class="data row0 col0" >35</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col1" class="data row0 col1" >48</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col2" class="data row0 col2" >164</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col3" class="data row0 col3" >51</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row0_col7" class="data row0 col7" >298</td>
#             </tr>
#             <tr>
#                         <th id="T_7e8a8f4a_3635_11ee_b87a_415645000030level0_row1" class="row_heading level0 row1" >Construction</th>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col0" class="data row1 col0" >218</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col1" class="data row1 col1" >543</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col2" class="data row1 col2" >384</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col3" class="data row1 col3" >410</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col4" class="data row1 col4" >82</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row1_col7" class="data row1 col7" >1,637</td>
#             </tr>
#             <tr>
#                         <th id="T_7e8a8f4a_3635_11ee_b87a_415645000030level0_row2" class="row_heading level0 row2" >Education/Other public services</th>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col0" class="data row2 col0" >142</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col1" class="data row2 col1" >205</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col2" class="data row2 col2" >53</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col3" class="data row2 col3" >205</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col4" class="data row2 col4" >457</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col5" class="data row2 col5" >372</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col6" class="data row2 col6" >127</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row2_col7" class="data row2 col7" >1,561</td>
#             </tr>
#             <tr>
#                         <th id="T_7e8a8f4a_3635_11ee_b87a_415645000030level0_row3" class="row_heading level0 row3" >Industrial/Utilities</th>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col0" class="data row3 col0" >25</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col2" class="data row3 col2" >33</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col3" class="data row3 col3" >59</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col4" class="data row3 col4" >526</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col5" class="data row3 col5" >105</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row3_col7" class="data row3 col7" >748</td>
#             </tr>
#             <tr>
#                         <th id="T_7e8a8f4a_3635_11ee_b87a_415645000030level0_row4" class="row_heading level0 row4" >Info/Finance/Insurance/Real Estate/Professional services</th>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col0" class="data row4 col0" >301</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col1" class="data row4 col1" >475</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col2" class="data row4 col2" >183</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col3" class="data row4 col3" >252</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col4" class="data row4 col4" >204</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col6" class="data row4 col6" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row4_col7" class="data row4 col7" >1,415</td>
#             </tr>
#             <tr>
#                         <th id="T_7e8a8f4a_3635_11ee_b87a_415645000030level0_row5" class="row_heading level0 row5" >Leisure/Accommodations and Food</th>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col0" class="data row5 col0" >98</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col1" class="data row5 col1" >168</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col2" class="data row5 col2" >38</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col3" class="data row5 col3" >71</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col4" class="data row5 col4" >4</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col6" class="data row5 col6" >3</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row5_col7" class="data row5 col7" >382</td>
#             </tr>
#             <tr>
#                         <th id="T_7e8a8f4a_3635_11ee_b87a_415645000030level0_row6" class="row_heading level0 row6" >Manufacturing</th>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row6_col0" class="data row6 col0" >81</td>
#                         <td id="T_7e8a8f4a_3635_11ee_b87a_415645000030row6_col1" class="data row6 col1" >201</td>

# %%
print("Trips by Industry and Size Class -- Weighted")
pivot2
# Out:
# Trips by Industry and Size Class -- Weighted
# <style  type="text/css" >
# </style><table id="T_7e99f89e_3635_11ee_b06b_415645000030" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=8>wtd_trips</th>    </tr>    <tr>        <th class="index_name level1" >emp_szclass</th>        <th class="col_heading level1 col0" >1</th>        <th class="col_heading level1 col1" >2</th>        <th class="col_heading level1 col2" >3</th>        <th class="col_heading level1 col3" >4</th>        <th class="col_heading level1 col4" >5</th>        <th class="col_heading level1 col5" >6</th>        <th class="col_heading level1 col6" >7</th>        <th class="col_heading level1 col7" >Totals</th>    </tr>    <tr>        <th class="index_name level0" >industry_group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7e99f89e_3635_11ee_b06b_415645000030level0_row0" class="row_heading level0 row0" >Agriculture/Mining</th>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col0" class="data row0 col0" >520</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col1" class="data row0 col1" >2,764</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col2" class="data row0 col2" >8,331</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col3" class="data row0 col3" >539</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row0_col7" class="data row0 col7" >12,154</td>
#             </tr>
#             <tr>
#                         <th id="T_7e99f89e_3635_11ee_b06b_415645000030level0_row1" class="row_heading level0 row1" >Construction</th>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col0" class="data row1 col0" >37,860</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col1" class="data row1 col1" >83,509</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col2" class="data row1 col2" >29,684</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col3" class="data row1 col3" >34,012</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col4" class="data row1 col4" >15,875</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row1_col7" class="data row1 col7" >200,940</td>
#             </tr>
#             <tr>
#                         <th id="T_7e99f89e_3635_11ee_b06b_415645000030level0_row2" class="row_heading level0 row2" >Education/Other public services</th>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col0" class="data row2 col0" >25,251</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col1" class="data row2 col1" >84,412</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col2" class="data row2 col2" >12,726</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col3" class="data row2 col3" >49,223</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col4" class="data row2 col4" >164,376</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col5" class="data row2 col5" >133,217</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col6" class="data row2 col6" >69,462</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row2_col7" class="data row2 col7" >538,667</td>
#             </tr>
#             <tr>
#                         <th id="T_7e99f89e_3635_11ee_b06b_415645000030level0_row3" class="row_heading level0 row3" >Industrial/Utilities</th>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col0" class="data row3 col0" >364</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col2" class="data row3 col2" >481</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col3" class="data row3 col3" >860</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col4" class="data row3 col4" >12,423</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col5" class="data row3 col5" >6,993</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row3_col7" class="data row3 col7" >21,121</td>
#             </tr>
#             <tr>
#                         <th id="T_7e99f89e_3635_11ee_b06b_415645000030level0_row4" class="row_heading level0 row4" >Info/Finance/Insurance/Real Estate/Professional services</th>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col0" class="data row4 col0" >49,139</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col1" class="data row4 col1" >80,555</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col2" class="data row4 col2" >30,789</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col3" class="data row4 col3" >57,204</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col4" class="data row4 col4" >44,338</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col6" class="data row4 col6" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row4_col7" class="data row4 col7" >262,025</td>
#             </tr>
#             <tr>
#                         <th id="T_7e99f89e_3635_11ee_b06b_415645000030level0_row5" class="row_heading level0 row5" >Leisure/Accommodations and Food</th>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col0" class="data row5 col0" >9,680</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col1" class="data row5 col1" >13,164</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col2" class="data row5 col2" >5,234</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col3" class="data row5 col3" >9,779</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col4" class="data row5 col4" >550</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col6" class="data row5 col6" >413</td>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row5_col7" class="data row5 col7" >38,820</td>
#             </tr>
#             <tr>
#                         <th id="T_7e99f89e_3635_11ee_b06b_415645000030level0_row6" class="row_heading level0 row6" >Manufacturing</th>
#                         <td id="T_7e99f89e_3635_11ee_b06b_415645000030row6_col0" class="data row6 col0" >4,944</td>
#                         <

# %%
# Group number of home deliveries by establishment
df_homeDeliv = df_trips[(df_trips['activity_type']==5) & \
                        (df_trips['placetype']==11)].groupby(['industry_group']).size().reset_index(name='n_stops')

df_homeDeliv = df_trips[(df_trips['placetype']==11)].groupby(['industry_group']).size().reset_index(name='n_stops')
df_homeDeliv
# Out:
#                                        industry_group  n_stops
# 0                                  Agriculture/Mining       71
# 1                                        Construction      439
# 2                     Education/Other public services      451
# 3                                Industrial/Utilities      216
# 4   Info/Finance/Insurance/Real Estate/Professiona...      327
# 5                     Leisure/Accommodations and Food       55
# 6                                       Manufacturing      130
# 7                             Medical/Health Services      788
# 8                                              Retail      169
# 9                                      Transportation      496
# 10                                          Wholesale      193

# %%
# Group number of home deliveries by establishment
df_homeDeliv = df_trips[(df_trips['activity_type']==5) & \
                        (df_trips['placetype']==11)].groupby(['industry_group'])['Most Likely Estimate Weight Factor'].sum().astype('int64').reset_index(name='wtd_stops')

df_homeDeliv = df_trips[(df_trips['placetype']==11)].groupby(['industry_group'])['Most Likely Estimate Weight Factor'].sum().astype('int64').reset_index(name='wtd_stops')
food = df_homeDeliv[df_homeDeliv['industry_group'].isin(['Leisure/Accommodations and Food','Retail'])].sum().reset_index(name='wtd_stops')

df_homeDeliv['wtd_stops'] = df_homeDeliv['wtd_stops'].map('{:,d}'.format)
print(df_homeDeliv.to_string(index=False))
# Out:
#                                     industry_group wtd_stops
#                                 Agriculture/Mining     2,271
#                                       Construction    49,452
#                    Education/Other public services   168,815
#                               Industrial/Utilities     4,163
#  Info/Finance/Insurance/Real Estate/Professiona...    56,478
#                    Leisure/Accommodations and Food     5,534
#                                      Manufacturing    15,865
#                            Medical/Health Services   233,709
#                                             Retail    14,673
#                                     Transportation    29,671
#                                          Wholesale    12,737

# %%
print(f"Maximum number of residential stops for retail and food: {food.iloc[1]['wtd_stops']:,}")
# Out:
# Maximum number of residential stops for retail and food: 20,207
